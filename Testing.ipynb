# Dataset5\Temulawak\Temulawak (90).jpg
# Dataset5\Temulawak\Temulawak (91).jpg
# Dataset5\Temulawak\Temulawak (92).jpg
# Dataset5\Temulawak\Temulawak (93).jpg
# Dataset5\Temulawak\Temulawak (94).jpg
# Dataset5\Temulawak\Temulawak (95).jpg
# Dataset5\Temulawak\Temulawak (96).jpg
# Dataset5\Temulawak\Temulawak (97).jpg
# Dataset5\Temulawak\Temulawak (98).jpg
# Dataset5\Temulawak\Temulawak (99).jpg

# %%
import pathlib

test_directory = "TESTREAL"
data_dir = "Dataset5"  # Datasets path
data_dir = pathlib.Path(data_dir)
data_dir
# Out:
# WindowsPath('Dataset5')

# %%
Jahe = list(data_dir.glob('Jahe/*'))[:25]
Kencur = list(data_dir.glob('Kencur/*'))[:25]
Kunyit = list(data_dir.glob('Kunyit/*'))[:25]
Lengkuas = list(data_dir.glob('Lengkuas/*'))[:25]
Temulawak = list(data_dir.glob('Temulawak/*'))[:25]

# %%
df_images = {
    'Jahe':  Jahe,
    'Kencur': Kencur,
    'Kunyit': Kunyit,
    'Lengkuas': Lengkuas,
    'Temulawak': Temulawak
}
df_labels = {
    'Jahe': 0,
    'Kencur': 1,
    'Kunyit': 2,
    'Lengkuas': 3,
    'Temulawak': 4
}

# %%
#from keras.preprocessing.image import ImageDataGenerator
#from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Rescaling
#from keras.models import Sequential
#from keras.utils.np_utils import to_categorical  # convert to one-hot-encoding
#from sklearn.metrics import confusion_matrix
#import pandas as pd

# %%
import cv2

X, y = [], []
for label, images in df_images.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img, (256, 256))
        X.append(resized_img)
        y.append(df_labels[label])

# %%
import numpy as np

X = np.array(X)
X = X/255
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
#Spliting into test val train
X_train, X_val, Y_train, Y_val = train_test_split(X, y, test_size=0.1, random_state=2)

# %%
batch_size = 25
img_height = 256
img_width = 256

# %%
import tensorflow as tf
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.4,
    subset="training",
    seed=1234,
    image_size=(img_height, img_width),
    batch_size=batch_size)
val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.4,
    subset="validation",
    seed=1234,
    image_size=(img_height, img_width),
    batch_size=batch_size)

test_ds = tf.keras.utils.image_dataset_from_directory(
   test_directory,
   #validation_split=0,
   image_size=(img_height, img_width),
   #subset="training",
   shuffle=True,
   batch_size=batch_size,
   seed=123)
# Out:
# Found 1000 files belonging to 5 classes.
# Using 600 files for training.
# Found 1000 files belonging to 5 classes.
# Using 400 files for validation.
# Found 200 files belonging to 5 classes.

# %%
train_ds.cardinality().numpy(),  test_ds.cardinality().numpy()
# Out:
# (24, 8)

# %%
train_set = train_ds.take(100)
val_set = train_ds.take(30)
# g guna

# %%
train_set.cardinality().numpy(), val_set.cardinality().numpy()
# Out:
# (24, 24)

# %%
# Cek 5 Kelas dataset
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Jahe', 'Kencur', 'Kunyit', 'Lengkuas', 'Temulawak']

# %%
# Cek Ukuran gambar input + image_batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (25, 256, 256, 3)
# (25,)

# %%
#data_dir = pathlib.Path('Dataset')

for label in train_ds.class_names:
  images = list(data_dir.glob(f'{label}/*'))
  print(f'{label} : {len(images)}')
# Out:
# Jahe : 200
# Kencur : 200
# Kunyit : 200
# Lengkuas : 200
# Temulawak : 200

# %%
#import matplotlib.pyplot as plt
#import random

# %%
# print random images from the train set
#plt.figure(figsize = (8, 8))
#for images, labels in train_ds.take(1):
 # for i in range(16):
  #  index = random.randint(0, len(images))
   # ax = plt.subplot(4, 4, i + 1)
    #plt.imshow(images[index].numpy().astype("uint8"))
    #plt.title(train_ds.class_names[labels[index]])
    #plt.axis(False)

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
num_classes = len(class_names)

model = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.Conv2D(16, kernel_size=5, padding='same', activation='relu'),
    layers.MaxPool2D(),
    layers.Dropout(0.1),
    layers.Conv2D(40, kernel_size=5, padding='same', activation='relu'),
    layers.MaxPool2D(),
    layers.Dropout(0.1),
    #layers.Conv2D(128, kernel_size=5, padding='same', activation='relu'),
    #layers.MaxPool2D(),
    #layers.Dropout(0.1),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(
                  from_logits=True),
              metrics=['accuracy'])
              
callbacks = [
    keras.callbacks.EarlyStopping(
        # Stop training when `val_loss` is no longer improving
        monitor="val_loss",
        # "no longer improving" being defined as "no better than 1e-2 less"
        min_delta=1e-2,
        # "no longer improving" being further defined as "for at least 2 epochs"
        patience=2,
        verbose=1,
    )
]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 256, 256, 16)      1216
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  dropout (Dropout)           (None, 128, 128, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 40)      16040
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 40)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 40)        0
#
#  flatten (Flatten)           (None, 163840)            0
#
#  dense (Dense)               (None, 512)               83886592
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 83,906,413
# Trainable params: 83,906,413
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 20

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    #callbacks=callbacks
)


# MODEL ini training selama 2 menit untuk 20 epoch
# Out:
# Epoch 1/20
# 24/24 [==============================] - 48s 2s/step - loss: 11.7836 - accuracy: 0.2933 - val_loss: 1.4439 - val_accuracy: 0.6525
# Epoch 2/20
# 24/24 [==============================] - 45s 2s/step - loss: 0.8756 - accuracy: 0.6983 - val_loss: 0.3702 - val_accuracy: 0.9350
# Epoch 3/20
# 24/24 [==============================] - 44s 2s/step - loss: 0.1439 - accuracy: 0.9650 - val_loss: 0.0599 - val_accuracy: 0.9900
# Epoch 4/20
# 24/24 [==============================] - 45s 2s/step - loss: 0.0227 - accuracy: 0.9933 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 5/20
# 24/24 [==============================] - 45s 2s/step - loss: 0.0086 - accuracy: 0.9983 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 6/20
# 24/24 [==============================] - 45s 2s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 7/20
# 24/24 [==============================] - 45s 2s/step - loss: 8.2434e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 8/20
# 24/24 [==============================] - 45s 2s/step - loss: 5.0426e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 9/20
# 24/24 [==============================] - 45s 2s/step - loss: 3.3029e-04 - accuracy: 1.0000 - val_loss: 7.8805e-04 - val_accuracy: 1.0000
# Epoch 10/20
# 24/24 [==============================] - 46s 2s/step - loss: 1.9389e-04 - accuracy: 1.0000 - val_loss: 8.8066e-04 - val_accuracy: 1.0000
# Epoch 11/20
# 24/24 [==============================] - 46s 2s/step - loss: 1.6298e-04 - accuracy: 1.0000 - val_loss: 4.9076e-04 - val_accuracy: 1.0000
# Epoch 12/20
# 24/24 [==============================] - 46s 2s/step - loss: 1.1840e-04 - accuracy: 1.0000 - val_loss: 4.8662e-04 - val_accuracy: 1.0000
# Epoch 13/20
# 24/24 [==============================] - 45s 2s/step - loss: 1.2394e-04 - accuracy: 1.0000 - val_loss: 4.4680e-04 - val_accuracy: 1.0000
# Epoch 14/20
# 24/24 [==============================] - 45s 2s/step - loss: 9.3818e-05 - accuracy: 1.0000 - val_loss: 4.0924e-04 - val_accuracy: 1.0000
# Epoch 15/20
# 24/24 [==============================] - 45s 2s/step - loss: 9.6689e-05 - accuracy: 1.0000 - val_loss: 3.8627e-04 - val_accuracy: 1.0000
# Epoch 16/20
# 24/24 [==============================] - 45s 2s/step - loss: 2.1562e-04 - accuracy: 1.0000 - val_loss: 3.2754e-04 - val_accuracy: 1.0000
# Epoch 17/20
# 24/24 [==============================] - 46s 2s/step - loss: 7.5318e-05 - accuracy: 1.0000 - val_loss: 2.9409e-04 - val_accuracy: 1.0000
# Epoch 18/20
# 24/24 [==============================] - 45s 2s/step - loss: 5.8701e-05 - accuracy: 1.0000 - val_loss: 3.1012e-04 - val_accuracy: 1.0000
# Epoch 19/20
# 24/24 [==============================] - 46s 2s/step - loss: 4.9863e-05 - accuracy: 1.0000 - val_loss: 2.7169e-04 - val_accuracy: 1.0000
# Epoch 20/20
# 24/24 [==============================] - 46s 2s/step - loss: 5.6874e-05 - accuracy: 1.0000 - val_loss: 2.4410e-04 - val_accuracy: 1.0000

# %%
model.evaluate(val_ds)
model.evaluate(train_ds)
# Out:
# 16/16 [==============================] - 8s 390ms/step - loss: 2.4410e-04 - accuracy: 1.0000
# 24/24 [==============================] - 11s 411ms/step - loss: 1.4102e-04 - accuracy: 1.0000
# [0.00014101988926995546, 1.0]

# %%
model.evaluate(test_ds)
# Out:
# 8/8 [==============================] - 5s 423ms/step - loss: 0.7736 - accuracy: 0.9200
# [0.7735593318939209, 0.9200000166893005]

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
d = history.history
plt.plot(range(epochs), d.get("loss"))
plt.ylabel("RMSE Loss")
plt.xlabel("epoch")

loss = d.get("loss")

for i in range(len(loss)):
    if i % 25 == 1:
        print(f"epoch: {i:3} loss: {loss[i]:10.8f}")
# Out:
# epoch:   1 loss: 0.87558156

# %%
X_test, y_test = None, None
for images, labels in test_ds.take(50):
  if X_test == None or y_test == None:
    X_test = images
    y_test = labels
  else:
    X_test = tf.concat([X_test, images], axis=0)
    y_test = tf.concat([y_test, labels], axis=0)

X_test.shape, y_test.shape
# Out:
# (TensorShape([200, 256, 256, 3]), TensorShape([200]))

# %%
from sklearn import metrics

# %%
#y_predd = model.predict(train_set)

# %%
y_pred_proba = model.predict(X_test)
y_pred = np.argmax(y_pred_proba, axis=1)
metrics.accuracy_score(y_test, y_pred)
# Out:
# 7/7 [==============================] - 3s 358ms/step
# 0.92

# %%
metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
# Out:
# 0.9225330299280999

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        40
#            1       1.00      1.00      1.00        40
#            2       1.00      0.93      0.96        40
#            3       0.90      0.88      0.89        40
#            4       0.75      0.90      0.82        40
#
#     accuracy                           0.92       200
#    macro avg       0.93      0.92      0.92       200
# weighted avg       0.93      0.92      0.92       200

# %%
import seaborn as sns

print(test_ds.class_names)
plt.figure(figsize=(9, 7.5), dpi=100)
sns.heatmap(metrics.confusion_matrix(
    y_test, y_pred), annot=True, cmap='inferno')
plt.xlabel('Predictions')
plt.ylabel('True Labels')
plt.title('Confusion Matrix by Renaldi Nafiawan')
plt.show()
# Out:
# ['Jahe', 'Kencur', 'Kunyit', 'Lengkuas', 'Temulawak']

# %%
# plot random images from a given dataset, and compare predictions with ground truth
def plot_random_predictions(dataset, model):

  shuffled_data = test_ds.shuffle(50)
  #class_names = dataset.class_names
  class_names = test_ds.class_names


  for images, labels in shuffled_data.take(1):
    plt.figure(figsize = (12, 12), dpi = 120)
    y_pred_proba = model.predict(images)

    for i in range(16):
      index = random.randint(0, len(images))
      ax = plt.subplot(4, 4, i + 1)

      img = images[index].numpy().astype("uint8")
      y_true = class_names[labels[index]]
      y_pred = class_names[np.argmax(y_pred_proba[index], axis = 0)]
      
      c = 'g' if y_pred == y_true else 'r'
      
      plt.imshow(img)
      plt.title(f'Predicted : {y_pred}\nTrue label : {y_true}', c = c)
      plt.axis(False)

# %%
import random 
plot_random_predictions(test_ds, model)
# Out:
# 1/1 [==============================] - 0s 380ms/step

# %%
model.save('Modelakhir')  # The file needs to end with the .keras extension
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Modelakhir\assets
# INFO:tensorflow:Assets written to: Modelakhir\assets

# %%
#model.save_weights("modelakhir.h5")

# serialize model to JSON
#model_json = model.to_json()
#with open("model.json", "w") as json_file:
 #   json_file.write(model_json)

# %% [markdown]
# ###Kalo mau ngeload

# %%
# later...
 
#### load json and create model
#json_file = open('model.json', 'r')
#loaded_model_json = json_file.read()
#json_file.close()
#loaded_model = model_from_json(loaded_model_json)
#### load weights into new model
#loaded_model.load_weights("modelakhir.h5")
#print("Loaded model from disk(berhasil-alan)")
 
#### evaluate loaded model on test data
#loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
#score = loaded_model.evaluate(X, Y, verbose=0)
#print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))

# Dataset4\Temulawak\tmlwk3_12.jpg
# Dataset4\Temulawak\tmlwk3_13.jpg
# Dataset4\Temulawak\tmlwk3_14.jpg
# Dataset4\Temulawak\tmlwk3_15.jpg
# Dataset4\Temulawak\tmlwk3_16.jpg
# Dataset4\Temulawak\tmlwk3_17.jpg
# Dataset4\Temulawak\tmlwk3_19.jpg
# Dataset4\Temulawak\tmlwk3_2.jpg
# Dataset4\Temulawak\tmlwk3_4.jpg
# Dataset4\Temulawak\tmlwk3_5.jpg
# Dataset4\Temulawak\tmlwk3_6.jpg
# Dataset4\Temulawak\tmlwk3_7.jpg
# Dataset4\Temulawak\tmlwk3_9.jpg
# Dataset4\Temulawak\tmlwk_10.jpg
# Dataset4\Temulawak\tmlwk_11.jpg
# Dataset4\Temulawak\tmlwk_13.jpg
# Dataset4\Temulawak\tmlwk_14.jpg
# Dataset4\Temulawak\tmlwk_15.jpg
# Dataset4\Temulawak\tmlwk_16.jpg
# Dataset4\Temulawak\tmlwk_17.jpg
# Dataset4\Temulawak\tmlwk_18.jpg
# Dataset4\Temulawak\tmlwk_2.jpg
# Dataset4\Temulawak\tmlwk_3.jpg
# Dataset4\Temulawak\tmlwk_5.jpg
# Dataset4\Temulawak\tmlwk_6.jpg
# Dataset4\Temulawak\tmlwk_7.jpg
# Dataset4\Temulawak\tmlwk_8.jpg

# %%
import pathlib

test_directory = "TESTREAL"
data_dir = "Dataset4"  # Datasets path
data_dir = pathlib.Path(data_dir)
data_dir
# Out:
# WindowsPath('Dataset4')

# %%
Jahe = list(data_dir.glob('Jahe/*'))[:25]
Kencur = list(data_dir.glob('Kencur/*'))[:25]
Kunyit = list(data_dir.glob('Kunyit/*'))[:25]
Lengkuas = list(data_dir.glob('Lengkuas/*'))[:25]
Temulawak = list(data_dir.glob('Temulawak/*'))[:25]

# %%
df_images = {
    'Jahe':  Jahe,
    'Kencur': Kencur,
    'Kunyit': Kunyit,
    'Lengkuas': Lengkuas,
    'Temulawak': Temulawak
}
df_labels = {
    'Jahe': 0,
    'Kencur': 1,
    'Kunyit': 2,
    'Lengkuas': 3,
    'Temulawak': 4
}

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Rescaling
from keras.models import Sequential
from keras.utils.np_utils import to_categorical  # convert to one-hot-encoding
from sklearn.metrics import confusion_matrix
import pandas as pd

# %%
import cv2

X, y = [], []
for label, images in df_images.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img, (256, 256))
        X.append(resized_img)
        y.append(df_labels[label])

# %%
import numpy as np

X = np.array(X)
X = X/255
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
#Spliting into test val train
X_train, X_val, Y_train, Y_val = train_test_split(X, y, test_size=0.1, random_state=2)

# %%
batch_size = 25
img_height = 256
img_width = 256

# %%
import tensorflow as tf
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.4,
    subset="training",
    seed=1234,
    image_size=(img_height, img_width),
    batch_size=batch_size)
val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.4,
    subset="validation",
    seed=1234,
    image_size=(img_height, img_width),
    batch_size=batch_size)

test_ds = tf.keras.utils.image_dataset_from_directory(
   test_directory,
   #validation_split=0,
   image_size=(img_height, img_width),
   #subset="training",
   shuffle=True,
   batch_size=batch_size,
   seed=123)
# Out:
# Found 205 files belonging to 5 classes.
# Using 123 files for training.
# Found 205 files belonging to 5 classes.
# Using 82 files for validation.
# Found 200 files belonging to 5 classes.

# %%
train_ds.cardinality().numpy(),  test_ds.cardinality().numpy()
# Out:
# (5, 8)

# %%
train_set = train_ds.take(100)
val_set = train_ds.take(30)
# g guna

# %%
train_set.cardinality().numpy(), val_set.cardinality().numpy()
# Out:
# (5, 5)

# %%
# Cek 5 Kelas dataset
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Jahe', 'Kencur', 'Kunyit', 'Lengkuas', 'Temulawak']

# %%
# Cek Ukuran gambar input + image_batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (25, 256, 256, 3)
# (25,)

# %%
#data_dir = pathlib.Path('Dataset')

for label in train_ds.class_names:
  images = list(data_dir.glob(f'{label}/*'))
  print(f'{label} : {len(images)}')
# Out:
# Jahe : 40
# Kencur : 42
# Kunyit : 41
# Lengkuas : 40
# Temulawak : 42

# %%
#import matplotlib.pyplot as plt
#import random

# %%
# print random images from the train set
#plt.figure(figsize = (8, 8))
#for images, labels in train_ds.take(1):
 # for i in range(16):
  #  index = random.randint(0, len(images))
   # ax = plt.subplot(4, 4, i + 1)
    #plt.imshow(images[index].numpy().astype("uint8"))
    #plt.title(train_ds.class_names[labels[index]])
    #plt.axis(False)

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
num_classes = len(class_names)

model = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.Conv2D(16, kernel_size=5, padding='same', activation='relu'),
    layers.MaxPool2D(),
    layers.Dropout(0.1),
    layers.Conv2D(40, kernel_size=5, padding='same', activation='relu'),
    layers.MaxPool2D(),
    layers.Dropout(0.1),
    #layers.Conv2D(128, kernel_size=5, padding='same', activation='relu'),
    #layers.MaxPool2D(),
    #layers.Dropout(0.1),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(
                  from_logits=True),
              metrics=['accuracy'])
              
callbacks = [
    keras.callbacks.EarlyStopping(
        # Stop training when `val_loss` is no longer improving
        monitor="val_loss",
        # "no longer improving" being defined as "no better than 1e-2 less"
        min_delta=1e-2,
        # "no longer improving" being further defined as "for at least 2 epochs"
        patience=2,
        verbose=1,
    )
]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 256, 256, 16)      1216
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  dropout (Dropout)           (None, 128, 128, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 40)      16040
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 40)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 40)        0
#
#  flatten (Flatten)           (None, 163840)            0
#
#  dense (Dense)               (None, 512)               83886592
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 83,906,413
# Trainable params: 83,906,413
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 10

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    #callbacks=callbacks
)


# MODEL ini training selama 2 menit untuk 20 epoch
# Out:
# Epoch 1/10
# 5/5 [==============================] - 9s 2s/step - loss: 50.1309 - accuracy: 0.1545 - val_loss: 6.7035 - val_accuracy: 0.2561
# Epoch 2/10
# 5/5 [==============================] - 8s 2s/step - loss: 7.7835 - accuracy: 0.1707 - val_loss: 1.6209 - val_accuracy: 0.2317
# Epoch 3/10
# 5/5 [==============================] - 9s 2s/step - loss: 1.6659 - accuracy: 0.2276 - val_loss: 1.5540 - val_accuracy: 0.6341
# Epoch 4/10
# 5/5 [==============================] - 9s 2s/step - loss: 1.5198 - accuracy: 0.3252 - val_loss: 1.4968 - val_accuracy: 0.3780
# Epoch 5/10
# 5/5 [==============================] - 9s 2s/step - loss: 1.2190 - accuracy: 0.5366 - val_loss: 1.3894 - val_accuracy: 0.4390
# Epoch 6/10
# 5/5 [==============================] - 8s 2s/step - loss: 1.0003 - accuracy: 0.6667 - val_loss: 1.1200 - val_accuracy: 0.5610
# Epoch 7/10
# 5/5 [==============================] - 8s 2s/step - loss: 0.6564 - accuracy: 0.8455 - val_loss: 0.9644 - val_accuracy: 0.5976
# Epoch 8/10
# 5/5 [==============================] - 8s 2s/step - loss: 0.3911 - accuracy: 0.9187 - val_loss: 0.9553 - val_accuracy: 0.5976
# Epoch 9/10
# 5/5 [==============================] - 8s 2s/step - loss: 0.3045 - accuracy: 0.9187 - val_loss: 1.0682 - val_accuracy: 0.6220
# Epoch 10/10
# 5/5 [==============================] - 9s 2s/step - loss: 0.1799 - accuracy: 0.9919 - val_loss: 0.8543 - val_accuracy: 0.7073

# %%
model.evaluate(val_ds)
model.evaluate(train_ds)
# Out:
# 4/4 [==============================] - 1s 211ms/step - loss: 0.8543 - accuracy: 0.7073
# 5/5 [==============================] - 2s 250ms/step - loss: 0.1402 - accuracy: 0.9919
# [0.14023232460021973, 0.9918699264526367]

# %%
model.evaluate(test_ds)
# Out:
# 8/8 [==============================] - 3s 284ms/step - loss: 0.5586 - accuracy: 0.8100
# [0.5586336851119995, 0.8100000023841858]

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
d = history.history
plt.plot(range(epochs), d.get("loss"))
plt.ylabel("RMSE Loss")
plt.xlabel("epoch")

loss = d.get("loss")

for i in range(len(loss)):
    if i % 25 == 1:
        print(f"epoch: {i:3} loss: {loss[i]:10.8f}")
# Out:
# epoch:   1 loss: 7.78346920

# %%
X_test, y_test = None, None
for images, labels in test_ds.take(50):
  if X_test == None or y_test == None:
    X_test = images
    y_test = labels
  else:
    X_test = tf.concat([X_test, images], axis=0)
    y_test = tf.concat([y_test, labels], axis=0)

X_test.shape, y_test.shape
# Out:
# (TensorShape([200, 256, 256, 3]), TensorShape([200]))

# %%
from sklearn import metrics

# %%
#y_predd = model.predict(train_set)

# %%
y_pred_proba = model.predict(X_test)
y_pred = np.argmax(y_pred_proba, axis=1)
metrics.accuracy_score(y_test, y_pred)
# Out:
# 7/7 [==============================] - 2s 303ms/step
# 0.81

# %%
metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
# Out:
# 0.8132220596093263

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.75      0.85        40
#            1       1.00      0.95      0.97        40
#            2       0.85      0.88      0.86        40
#            3       0.71      0.85      0.77        40
#            4       0.60      0.62      0.61        40
#
#     accuracy                           0.81       200
#    macro avg       0.82      0.81      0.81       200
# weighted avg       0.82      0.81      0.81       200

# %%
import seaborn as sns

print(test_ds.class_names)
plt.figure(figsize=(9, 7.5), dpi=100)
sns.heatmap(metrics.confusion_matrix(
    y_test, y_pred), annot=True, cmap='inferno')
plt.xlabel('Predictions')
plt.ylabel('True Labels')
plt.title('Confusion Matrix by Renaldi Nafiawan')
plt.show()
# Out:
# ['Jahe', 'Kencur', 'Kunyit', 'Lengkuas', 'Temulawak']

# %%
# plot random images from a given dataset, and compare predictions with ground truth
def plot_random_predictions(dataset, model):

  shuffled_data = test_ds.shuffle(50)
  #class_names = dataset.class_names
  class_names = test_ds.class_names


  for images, labels in shuffled_data.take(1):
    plt.figure(figsize = (12, 12), dpi = 120)
    y_pred_proba = model.predict(images)

    for i in range(16):
      index = random.randint(0, len(images))
      ax = plt.subplot(4, 4, i + 1)

      img = images[index].numpy().astype("uint8")
      y_true = class_names[labels[index]]
      y_pred = class_names[np.argmax(y_pred_proba[index], axis = 0)]
      
      c = 'g' if y_pred == y_true else 'r'
      
      plt.imshow(img)
      plt.title(f'Predicted : {y_pred}\nTrue label : {y_true}', c = c)
      plt.axis(False)

# %%
import random 
plot_random_predictions(test_ds, model)
# Out:
# 1/1 [==============================] - 0s 365ms/step

# %%
#model.save('Dataset')  # The file needs to end with the .keras extension
